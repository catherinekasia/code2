# %% [markdown]
# ### Visualisation of output
#
# This file provides some basic functionality for you to review the clustering of your implementation.
#
# If you do not change the I/O functions this should select the correct plotter for the output for each programming assignment.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import math
from sklearn import datasets

# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
plt.rcParams['figure.figsize'] = 6,6  # default hor./vert. size of plots, in inches
plt.rcParams['lines.markeredgewidth'] = 1  # to fix issue with seaborn box plots; needed after import seaborn

# %%
def ass_1(lines):
    n, d, c = lines[0].split()
    print(n, d, c)
    lines.pop(0)
    df = pd.DataFrame([[float(j) for j in i.split()] for i in lines[:-int(c)]])
    cd = [[float(j) for j in i.split()] for i in lines[-int(c):]]
    if d == '2':
        plot = df.plot(kind='scatter', x=0, y=1, c=df.columns.size-1, colormap='tab20', colorbar=False)
        x, y = zip(*cd)
        plot.scatter(x, y, marker='X', s=150, c=range(int(c)), cmap='tab20', linewidths=1, edgecolors='black')
    if d == '3':
        df.columns = ['x', 'y', 'z', 'c']
        sns.pairplot(df, vars=['x', 'y', 'z'], hue='c')

def ass_2(lines):
    n, d, c = lines[0].split()
    print(n, d, c)
    lines.pop(0)
    df = pd.DataFrame([[float(j) for j in i.split()] for i in lines])
    if d == '2':
        plot = df.plot(kind='scatter', x=0, y=1, c=2, colormap='tab20', colorbar=False)
    if d == '3':
        print()
        fig = plt.figure()
        ax = fig.add_subplot(111, projection='3d')
        xs = df.iloc[:,0].tolist()
        ys = df.iloc[:,1].tolist()
        zs = df.iloc[:,2].tolist()
        c = df.iloc[:,3].tolist()
        ax.scatter(xs, ys, zs, c=c, cmap='tab20')

plotters = {
    '1': ass_1,
    '2': ass_2,
    '3': ass_2
}

# %%
def plot_file(fl):
    with open(fl) as f:
        lines = f.read().splitlines()
    a = lines[0].split()[0]
    print(a)
    lines.pop(0)
    plotters[a](lines)

# %% [markdown]
# Make sure the path is correct to wherever you print your output

# %%
plot_file('./output/00.out')
# Out:
# 2
# 1000 2 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plot_file('./output/00.out')
#
# Cell In[3], line 7, in plot_file(fl)
#       5 print(a)
#       6 lines.pop(0)
# ----> 7 plotters[a](lines)
#
# Cell In[2], line 19, in ass_2(lines)
#      17 print(n, d, c)
#      18 lines.pop(0)
# ---> 19 df = pd.DataFrame([[float(j) for j in i.split()] for i in lines])
#      20 if d == '2':
#      21     plot = df.plot(kind='scatter', x=0, y=1, c=2, colormap='tab20', colorbar=False)
#
# Cell In[2], line 19, in <listcomp>(.0)
#      17 print(n, d, c)
#      18 lines.pop(0)
# ---> 19 df = pd.DataFrame([[float(j) for j in i.split()] for i in lines])
#      20 if d == '2':
#      21     plot = df.plot(kind='scatter', x=0, y=1, c=2, colormap='tab20', colorbar=False)
#
# Cell In[2], line 19, in <listcomp>(.0)
#      17 print(n, d, c)
#      18 lines.pop(0)
# ---> 19 df = pd.DataFrame([[float(j) for j in i.split()] for i in lines])
#      20 if d == '2':
#      21     plot = df.plot(kind='scatter', x=0, y=1, c=2, colormap='tab20', colorbar=False)
#
# ValueError: could not convert string to float: 'CORE'

# %%
plot_file('./output/01.out')

# %%
plot_file('./output/02.out')

# %%
plot_file('./output/03.out')

# %%
plot_file('./output/04.out')

# %%
plot_file('./output/05.out')

# %%
plot_file('./output/06.out')

# %%
plot_file('./output/07.out')
